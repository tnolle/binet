# %%
import pandas as pd
import networkx as nx
import numpy as np
from tqdm import tqdm

from april import Dataset
from april.processmining import ProcessMap
from april.fs import get_event_log_files
from april.fs import get_process_model_files

# %% [markdown]
# # Event Log information

# %% [markdown]
# A list of all event logs used in the evaluation

# %%
logs = sorted([e.name for e in get_event_log_files() if e.p == 0.3])
columns = ['name', 'base_name', 'num_cases', 'num_events', 'num_activities', 
           'num_attributes', 'attribute_keys', 'attribute_dims', 
           'min_attribute_dim', 'max_attribute_dim',
           'min_case_len', 'max_case_len', 'mean_case_len']
df = []
for log in tqdm(logs):
    d = Dataset(log)
    dim_min = d.attribute_dims[1:].astype(int).min() if d.attribute_dims[1:].size else None
    dim_max = d.attribute_dims[1:].astype(int).max() if d.attribute_dims[1:].size else None
    df.append([log, log.split('-')[0], d.num_cases, d.num_events, d.attribute_dims[0].astype(int), 
               d.num_attributes - 1, d.attribute_keys[1:], d.attribute_dims[1:].astype(int), dim_min, dim_max,
               d.case_lens.min(), d.case_lens.max(), d.case_lens.mean().round(2)])
event_logs = pd.DataFrame(df, columns=columns)
# Out:
# 100%|██████████| 44/44 [00:03<00:00, 11.93it/s]

# %% [markdown]
# ## Basis for Table 1 in the Paper

# %%
event_logs
# Out:
#               name base_name  num_cases  num_events  num_activities  \
# 0     bpic12-0.3-1    bpic12      13087      290424              73
# 1     bpic13-0.3-1    bpic13       1487        9793              15
# 2     bpic13-0.3-2    bpic13       7554       81427              27
# 3     bpic13-0.3-3    bpic13        819        4043              11
# 4     bpic15-0.3-1    bpic15       1199       54770             466
# 5     bpic15-0.3-2    bpic15        832       46089             474
# 6     bpic15-0.3-3    bpic15       1409       62665             486
# 7     bpic15-0.3-4    bpic15       1053       49493             422
# 8     bpic15-0.3-5    bpic15       1156       61465             446
# 9     bpic17-0.3-1    bpic17      31509     1268704              53
# 10    bpic17-0.3-2    bpic17      42995      284664              17
# 11  gigantic-0.3-1  gigantic       5000       39692             154
# 12  gigantic-0.3-2  gigantic       5000       38744             154
# 13  gigantic-0.3-3  gigantic       5000       42259             156
# 14  gigantic-0.3-4  gigantic       5000       41253             157
# 15      huge-0.3-1      huge       5000       53127             109
# 16      huge-0.3-2      huge       5000       46944             109
# 17      huge-0.3-3      huge       5000       53614             109
# 18      huge-0.3-4      huge       5000       50033             109
# 19     large-0.3-1     large       5000       67487              85
# 20     large-0.3-2     large       5000       61716              85
# 21     large-0.3-3     large       5000       64707              85
# 22     large-0.3-4     large       5000       63452              85
# 23    medium-0.3-1    medium       5000       42013              65
# 24    medium-0.3-2    medium       5000       39948              65
# 25    medium-0.3-3    medium       5000       39071              65
# 26    medium-0.3-4    medium       5000       39680              65
# 27       p2p-0.3-1       p2p       5000       53174              27
# 28       p2p-0.3-2       p2p       5000       48484              27
# 29       p2p-0.3-3       p2p       5000       49962              27
# 30       p2p-0.3-4       p2p       5000       52157              27
# 31     paper-0.3-1     paper       5000       66814              27
# 32      real-0.3-1      real        968        6933              19
# 33      real-0.3-2      real       8395       36738              37
# 34      real-0.3-3      real      17553       79861              23
# 35      real-0.3-4      real      16163       82238              21
# 36     small-0.3-1     small       5000       53492              41
# 37     small-0.3-2     small       5000       55178              41
# 38     small-0.3-3     small       5000       53963              41
# 39     small-0.3-4     small       5000       56723              41
# 40      wide-0.3-1      wide       5000       41889              68
# 41      wide-0.3-2      wide       5000       39827              68
# 42      wide-0.3-3      wide       5000       39958              69
# 43      wide-0.3-4      wide       5000       39718              69
#
#     num_attributes                                     attribute_keys  \
# 0                0                                                 []
# 1                4  [org_group, org_resource, organization_country...
# 2                4  [org_group, org_resource, organization_country...
# 3                2                          [org_group, org_resource]
# 4                2                 [monitoringResource, org_resource]
# 5                2                 [monitoringResource, org_resource]
# 6                3    [action_code, monitoringResource, org_resource]
# 7                2                 [monitoringResource, org_resource]
# 8                2                 [monitoringResource, org_resource]
# 9                1                                     [org_resource]
# 10               1                                     [org_resource]
# 11               1                                             [user]
# 12               2                                        [day, user]
# 13               3                               [country, day, user]
# 14               4                      [company, country, day, user]
# 15               1                                             [user]
# 16               2                                        [day, user]
# 17               3                               [country, day, user]
# 18               4                      [company, country, day, user]
# 19               1                                             [user]
# 20               2                                        [day, user]
# 21               3                               [country, day, user]
# 22               4                      [company, country, day, user]
# 23               1                                             [user]
# 24               2                                        [day, user]
# 25               3                               [country, day, user]
# 26               4                      [company, country, day, user]
# 27               1                                             [user]
# 28               2                                        [day, user]
# 29               3                               [country, day, user]
# 30               4                      [company, country, day, user]
# 31               1                                             [user]
# 32               1                                         [resource]
# 33               1                                         [resource]
# 34               1                                         [resource]
# 35               1                                         [resource]
# 36               1                                             [user]
# 37               2                                        [day, user]
# 38               3                               [country, day, user]
# 39               4                      [company, country, day, user]
# 40               1                                             [user]
# 41               2                                        [day, user]
# 42               3                               [country, day, user]
# 43               4                      [company, country, day, user]
#
#          attribute_dims  min_attribute_dim  max_attribute_dim  min_case_len  \
# 0                    []                NaN                NaN             3
# 1     [31, 657, 35, 43]               31.0              657.0             3
# 2   [987, 1836, 47, 65]               47.0             1836.0             3
# 3             [23, 267]               23.0              267.0             3
# 4              [53, 47]               47.0               53.0             4
# 5              [19, 23]               19.0               23.0             3
# 6         [481, 45, 29]               29.0              481.0             5
# 7              [25, 21]               21.0               25.0             3
# 8              [33, 43]               33.0               43.0             7
# 9                 [299]              299.0              299.0            10
# 10                [289]              289.0              289.0             3
# 11                [141]              141.0              141.0             3
# 12            [13, 140]               13.0              140.0             3
# 13       [408, 13, 141]               13.0              408.0             3
# 14  [149, 409, 13, 140]               13.0              409.0             3
# 15                [141]              141.0              141.0             5
# 16            [13, 141]               13.0              141.0             5
# 17       [420, 13, 141]               13.0              420.0             5
# 18  [149, 420, 13, 141]               13.0              420.0             5
# 19                [141]              141.0              141.0            10
# 20            [13, 141]               13.0              141.0            10
# 21       [398, 13, 141]               13.0              398.0            10
# 22  [150, 386, 13, 141]               13.0              386.0            10
# 23                [140]              140.0              140.0             3
# 24            [13, 141]               13.0              141.0             3
# 25       [383, 13, 141]               13.0              383.0             3
# 26  [151, 398, 13, 141]               13.0              398.0             3
# 27                [141]              141.0              141.0             7
# 28            [13, 141]               13.0              141.0             7
# 29       [386, 13, 139]               13.0              386.0             7
# 30  [148, 339, 13, 139]               13.0              339.0             7
# 31                 [13]               13.0               13.0             9
# 32                [160]              160.0              160.0             3
# 33                [294]              294.0              294.0             3
# 34                [362]              362.0              362.0             3
# 35                [325]              325.0              325.0             3
# 36                [141]              141.0              141.0             7
# 37            [13, 141]               13.0              141.0             7
# 38       [360, 13, 141]               13.0              360.0             7
# 39  [146, 359, 13, 138]               13.0              359.0             7
# 40                [141]              141.0              141.0             5
# 41            [13, 140]               13.0              140.0             5
# 42       [382, 13, 141]               13.0              382.0             5
# 43  [148, 380, 13, 141]               13.0              380.0             5
#
#     max_case_len  mean_case_len
# 0            175          22.19
# 1             37           6.59
# 2            125          10.78
# 3             24           4.94
# 4            104          45.68
# 5            134          55.40
# 6            126          44.47
# 7            118          47.00
# 8            156          53.17
# 9            182          40.26
# 10            10           6.62
# 11            16           7.94
# 12            16           7.75
# 13            16           8.45
# 14            16           8.25
# 15            16          10.63
# 16            15           9.39
# 17            16          10.72
# 18            16          10.01
# 19            17          13.50
# 20            17          12.34
# 21            17          12.94
# 22            17          12.69
# 23            13           8.40
# 24            13           7.99
# 25            13           7.81
# 26            13           7.94
# 27            16          10.63
# 28            16           9.70
# 29            15           9.99
# 30            16          10.43
# 31            17          13.36
# 32            12           7.16
# 33            16           4.38
# 34            10           4.55
# 35            12           5.09
# 36            15          10.70
# 37            15          11.04
# 38            15          10.79
# 39            15          11.34
# 40            12           8.38
# 41            12           7.97
# 42            12           7.99
# 43            12           7.94

# %%
event_logs[['base_name', 'num_activities', 'num_cases', 'num_events', 'min_attribute_dim', 'max_attribute_dim']].groupby('base_name').agg(['count', 'min', 'max'])
# Out:
#           num_activities           num_cases               num_events          \
#                    count  min  max     count    min    max      count     min
# base_name
# bpic12                 1   73   73         1  13087  13087          1  290424
# bpic13                 3   11   27         3    819   7554          3    4043
# bpic15                 5  422  486         5    832   1409          5   46089
# bpic17                 2   17   53         2  31509  42995          2  284664
# gigantic               4  154  157         4   5000   5000          4   38744
# huge                   4  109  109         4   5000   5000          4   46944
# large                  4   85   85         4   5000   5000          4   61716
# medium                 4   65   65         4   5000   5000          4   39071
# p2p                    4   27   27         4   5000   5000          4   48484
# paper                  1   27   27         1   5000   5000          1   66814
# real                   4   19   37         4    968  17553          4    6933
# small                  4   41   41         4   5000   5000          4   53492
# wide                   4   68   69         4   5000   5000          4   39718
#
#                    min_attribute_dim               max_attribute_dim         \
#                max             count    min    max             count    min
# base_name
# bpic12      290424                 0    NaN    NaN                 0    NaN
# bpic13       81427                 3   23.0   47.0                 3  267.0
# bpic15       62665                 5   19.0   47.0                 5   23.0
# bpic17     1268704                 2  289.0  299.0                 2  289.0
# gigantic     42259                 4   13.0  141.0                 4  140.0
# huge         53614                 4   13.0  141.0                 4  141.0
# large        67487                 4   13.0  141.0                 4  141.0
# medium       42013                 4   13.0  140.0                 4  140.0
# p2p          53174                 4   13.0  141.0                 4  141.0
# paper        66814                 1   13.0   13.0                 1   13.0
# real         82238                 4  160.0  362.0                 4  160.0
# small        56723                 4   13.0  141.0                 4  141.0
# wide         41889                 4   13.0  141.0                 4  140.0
#
#
#               max
# base_name
# bpic12        NaN
# bpic13     1836.0
# bpic15      481.0
# bpic17      299.0
# gigantic    409.0
# huge        420.0
# large       398.0
# medium      398.0
# p2p         386.0
# paper        13.0
# real        362.0
# small       360.0
# wide        382.0

# %% [markdown]
# # Process Model Information

# %%
maps = sorted([m for m in get_process_model_files()])
df = []
for process_map in tqdm(maps):
    model = ProcessMap.from_plg(process_map)

    num_variants = len(model.variants.cases)
    max_case_len = model.variants.max_case_len

    nodes = model.graph.number_of_nodes()
    edges = model.graph.number_of_edges()
    dens = nx.density(model.graph)
    in_degree = np.mean([d[1] for d in model.graph.in_degree()])
    out_degree = np.mean([d[1] for d in model.graph.out_degree()])

    df.append([nodes, edges, num_variants, max_case_len, dens, in_degree, out_degree])
process_models = pd.DataFrame(df, index=maps, columns=['nodes', 'edges', 'num_variants', 'max_case_len', 'density', 'in_deg', 'out_deg'])
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 45.06it/s]

# %%
process_models.loc[['paper', 'p2p', 'small', 'medium', 'large', 'huge', 'gigantic', 'wide', 'testing']].round(2)
# Out:
#           nodes  edges  num_variants   ...     density  in_deg  out_deg
# paper        16     18             8   ...        0.08    1.12     1.12
# p2p          15     18             8   ...        0.09    1.20     1.20
# small        22     26             6   ...        0.06    1.18     1.18
# medium       34     48            25   ...        0.04    1.41     1.41
# large        44     56            28   ...        0.03    1.27     1.27
# huge         56     75            39   ...        0.02    1.34     1.34
# gigantic     80    119            71   ...        0.02    1.49     1.49
# wide         36     53            19   ...        0.04    1.47     1.47
# testing     129    182            63   ...        0.01    1.41     1.41
#
# [9 rows x 7 columns]
